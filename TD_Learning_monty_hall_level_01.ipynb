# %%
from Costum_environments.monty_hall_paradox import MontyHallLevel01Env
from DRL_algorithms.utils import plot_deterministic_policy
from DRL_algorithms.td_learning import expected_sarsa_control

# %%
env = MontyHallLevel01Env()
policy_sarsa_monty_01, Q_sarsa_monty_01 = expected_sarsa_control(env,100000)
print(policy_sarsa_monty_01)
plot_deterministic_policy(policy_sarsa_monty_01)
# Out:
# {('second_choice', 0, 1): 'switch', ('second_choice', 0, 2): 'switch', ('second_choice', 1, 0): 'switch', ('second_choice', 1, 2): 'switch', ('second_choice', 2, 0): 'switch', ('second_choice', 2, 1): 'switch', ('start', None, None): 2}
