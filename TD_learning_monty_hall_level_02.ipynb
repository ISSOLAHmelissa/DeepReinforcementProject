# %%
from Costum_environments.monty_hall_paradox import MontyHallLevel02Env
from DRL_algorithms.td_learning import sarsa_control
import sys
sys.path.append("..")
from secret_envs.td_learning import q_learning

# %%
def print_sarsa_final_choices(policy):
    print("📋 Politique SARSA sur les états 'final_choice' :\n")
    for state, action in policy.items():
        if isinstance(state, tuple) and state[0] == 'final_choice':
            print(f"État {state} ➡️ Action : {action}")

# %%
env =  MontyHallLevel02Env()

# %%
policy_sarsa_monty_02, Q_sarsa_monty_02 = sarsa_control(env,100000,0.1,0.99,0.9)
print(policy_sarsa_monty_02)
print(f"Nombre d'états dans la politique : {len(policy_sarsa_monty_02)}")
# Out:
# {('start', (), ()): 3, ('start', (np.int64(0),), (3,)): 1, ('start', (np.int64(0), np.int64(2)), (3, 4)): 0, ('final_choice', np.int64(1), 0): 'switch', ('start', (np.int64(4),), (0,)): 4, ('start', (np.int64(4), np.int64(4)), (0, 1)): 3, ('final_choice', np.int64(3), 2): 'switch', ('start', (np.int64(3),), (0,)): 3, ('start', (np.int64(3), np.int64(4)), (0, 2)): 3, ('final_choice', np.int64(4), 3): 'switch', ('start', (np.int64(4),), (3,)): 4, ('start', (np.int64(4), np.int64(2)), (3, 4)): 2, ('final_choice', np.int64(2), 1): 'switch', ('start', (np.int64(3),), (1,)): 3, ('start', (np.int64(3), np.int64(0)), (1, 2)): 3, ('final_choice', np.int64(4), 0): 'switch', ('start', (np.int64(2),), (3,)): 0, ('start', (np.int64(2), np.int64(0)), (3, 1)): 0, ('final_choice', np.int64(0), 4): 'switch', ('start', (np.int64(1),), (2,)): 4, ('start', (np.int64(1), np.int64(0)), (2, 1)): 4, ('final_choice', np.int64(3), 0): 'switch', ('start', (np.int64(0), np.int64(2)), (3, 1)): 0, ('final_choice', np.int64(4), 2): 'switch', ('start', (np.int64(2), np.int64(4)), (3, 2)): 1, ('final_choice', np.int64(4), 1): 'switch', ('start', (np.int64(4),), (1,)): 2, ('start', (np.int64(4), np.int64(0)), (1, 3)): 4, ('final_choice', np.int64(0), 2): 'switch', ('start', (np.int64(0),), (4,)): 2, ('start', (np.int64(0), np.int64(2)), (4, 1)): 0, ('start', (np.int64(2),), (4,)): 3, ('start', (np.int64(2), np.int64(3)), (4, 1)): 2, ('start', (np.int64(1), np.int64(1)), (2, 4)): 3, ('final_choice', np.int64(3), 1): 'switch', ('final_choice', np.int64(2), 0): 'switch', ('start', (np.int64(0),), (1,)): 3, ('start', (np.int64(0), np.int64(3)), (1, 4)): 3, ('final_choice', np.int64(0), 3): 'switch', ('start', (np.int64(3),), (2,)): 4, ('start', (np.int64(3), np.int64(0)), (2, 1)): 3, ('start', (np.int64(4), np.int64(2)), (3, 1)): 2, ('start', (np.int64(0), np.int64(4)), (3, 0)): 4, ('final_choice', np.int64(1), 4): 'switch', ('start', (np.int64(2),), (0,)): 4, ('start', (np.int64(2), np.int64(4)), (0, 2)): 1, ('start', (np.int64(0), np.int64(3)), (4, 1)): 2, ('final_choice', np.int64(2), 3): 'switch', ('start', (np.int64(0), np.int64(1)), (4, 2)): 3, ('final_choice', np.int64(1), 3): 'switch', ('start', (np.int64(1),), (3,)): 0, ('start', (np.int64(1), np.int64(0)), (3, 1)): 0, ('final_choice', np.int64(2), 4): 'switch', ('start', (np.int64(1),), (4,)): 3, ('start', (np.int64(1), np.int64(1)), (4, 3)): 1, ('start', (np.int64(4), np.int64(0)), (3, 1)): 4, ('start', (np.int64(2),), (1,)): 3, ('start', (np.int64(2), np.int64(4)), (1, 3)): 4, ('start', (np.int64(4), np.int64(1)), (0, 4)): 3, ('start', (np.int64(2), np.int64(2)), (0, 1)): 4, ('start', (np.int64(4), np.int64(3)), (0, 4)): 1, ('start', (np.int64(3),), (4,)): 1, ('start', (np.int64(3), np.int64(3)), (4, 2)): 3, ('start', (np.int64(1), np.int64(0)), (3, 4)): 0, ('start', (np.int64(4), np.int64(4)), (1, 0)): 3, ('start', (np.int64(0),), (2,)): 3, ('start', (np.int64(0), np.int64(1)), (2, 4)): 3, ('start', (np.int64(0), np.int64(0)), (2, 4)): 0, ('start', (np.int64(0), np.int64(3)), (2, 1)): 0, ('start', (np.int64(1),), (0,)): 4, ('start', (np.int64(1), np.int64(2)), (0, 1)): 3, ('start', (np.int64(4), np.int64(4)), (1, 3)): 4, ('start', (np.int64(4), np.int64(3)), (1, 4)): 2, ('start', (np.int64(1), np.int64(1)), (3, 4)): 1, ('start', (np.int64(1), np.int64(3)), (0, 1)): 4, ('start', (np.int64(1), np.int64(1)), (3, 2)): 0, ('start', (np.int64(2), np.int64(2)), (1, 0)): 3, ('start', (np.int64(3), np.int64(2)), (0, 3)): 2, ('start', (np.int64(3), np.int64(2)), (4, 1)): 0, ('final_choice', np.int64(3), 4): 'switch', ('start', (np.int64(0), np.int64(0)), (3, 4)): 2, ('final_choice', np.int64(1), 2): 'switch', ('start', (np.int64(2), np.int64(1)), (3, 2)): 4, ('start', (np.int64(0), np.int64(4)), (2, 3)): 4, ('start', (np.int64(0), np.int64(3)), (2, 4)): 0, ('final_choice', np.int64(0), 1): 'switch', ('start', (np.int64(2), np.int64(0)), (3, 4)): 1, ('start', (np.int64(3), np.int64(2)), (0, 1)): 2, ('start', (np ...
# Nombre d'états dans la politique : 281

# %%
policy_Q_learning_monty_02, Q_q_learning_monty_02 = q_learning(env,100000,0.1,0.99,0.9)
print(policy_Q_learning_monty_02)
print(f"Nombre d'états dans la politique : {len(policy_Q_learning_monty_02)}")
# Out:
# {('start', (), ()): 2, ('start', (2,), (4,)): 2, ('start', (2, 2), (4, 1)): 2, ('final_choice', 0, 3): 'switch', ('start', (0,), (3,)): 4, ('start', (0, 2), (3, 4)): 2, ('final_choice', 1, 0): 'switch', ('start', (1,), (4,)): 3, ('start', (1, 2), (4, 3)): 2, ('final_choice', 0, 1): 'switch', ('start', (2,), (0,)): 4, ('start', (2, 1), (0, 2)): 4, ('final_choice', 1, 3): 'switch', ('start', (1,), (0,)): 3, ('start', (1, 2), (0, 1)): 4, ('final_choice', 2, 4): 'switch', ('start', (0, 0), (3, 4)): 2, ('start', (3,), (0,)): 3, ('start', (3, 1), (0, 3)): 4, ('final_choice', 2, 1): 'switch', ('start', (0,), (1,)): 2, ('start', (0, 3), (1, 0)): 2, ('start', (3, 4), (0, 3)): 2, ('final_choice', 1, 4): 'switch', ('start', (3,), (1,)): 2, ('start', (3, 2), (1, 3)): 0, ('final_choice', 4, 0): 'switch', ('start', (0, 3), (1, 4)): 2, ('final_choice', 3, 0): 'switch', ('start', (2,), (1,)): 2, ('start', (2, 4), (1, 2)): 4, ('start', (0,), (4,)): 0, ('start', (0, 0), (4, 3)): 2, ('start', (3,), (4,)): 2, ('start', (3, 3), (4, 2)): 3, ('start', (0, 1), (4, 2)): 3, ('start', (1,), (3,)): 4, ('start', (1, 0), (3, 2)): 4, ('final_choice', 4, 1): 'switch', ('start', (0, 2), (3, 1)): 0, ('final_choice', 0, 2): 'switch', ('start', (1, 1), (4, 3)): 0, ('final_choice', 2, 0): 'switch', ('start', (0