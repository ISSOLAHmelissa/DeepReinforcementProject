# %%
import sys
import os
from collections import defaultdict
import random
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), "..")))
from Costum_environments.TwoRoundRPS import TwoRoundRPS_AgentEnv
from DRL_algorithms.td_learning import sarsa_control,q_learning

# %%
env = TwoRoundRPS_AgentEnv()

# Apprentissage Q-Learning
policy_q, Q_q = q_learning(env, num_episodes=1000, alpha=0.1, gamma=0.95, epsilon=0.1)

# Affichage de la politique apprise (états connus)
print("Politique Q-Learning extraite (états connus) :")
for state in list(policy_q.keys())[:10]:
    print(f"État {state} → Action optimale : {policy_q[state]}")

# Affichage des valeurs Q apprises
print("\nValeurs Q apprises (extrait) :")
for state in list(Q_q.keys())[:10]:
    q_values = Q_q[state]
    for action, value in q_values.items():
        print(f"État {state} → {action}: {value:.3f}")
# Out:
# Politique Q-Learning extraite (états connus) :
# État ('start',) → Action optimale : scissors
# État ('second', 'rock') → Action optimale : rock
# État ('done',) → Action optimale : rock
# État ('second', 'paper') → Action optimale : scissors
# État ('second', 'scissors') → Action optimale : rock
#
# Valeurs Q apprises (extrait) :
# État ('start',) → rock: 0.162
# État ('start',) → paper: 0.707
# État ('start',) → scissors: 0.813
# État ('second', 'rock') → rock: 0.000
# État ('second', 'rock') → paper: 0.000
# État ('second', 'rock') → scissors: -0.190
# État ('done',) → rock: 0.000
# État ('done',) → paper: 0.000
# État ('done',) → scissors: 0.000
# État ('second', 'paper') → rock: -0.344
# État ('second', 'paper') → paper: 0.000
# État ('second', 'paper') → scissors: 1.000
# État ('second', 'scissors') → rock: 1.000
# État ('second', 'scissors') → paper: -0.891
# État ('second', 'scissors') → scissors: 0.000

# %%
env = TwoRoundRPS_AgentEnv()

# 2. Apprentissage avec Expected SARSA
policy, Q = sarsa_control(
    env=env,
    num_episodes=1000,
    alpha=0.1,
    gamma=0.99,
    epsilon=0.1
)

# 3. Affichage d’un extrait de la politique
print("Politique Expected SARSA extraite (états connus) :")
for i, (state, action) in enumerate(policy.items()):
    print(f"État {state} → Action optimale : {action}")
    if i >= 9:
        break
# 3. Affichage des valeurs Q apprises
print("\nValeurs Q apprises (extrait) :")
for i, (state, actions_q) in enumerate(Q.items()):
    line = f"État {state} → "
    line += ", ".join(f"{a}: {round(q, 3)}" for a, q in actions_q.items())
    print(line)
    if i >= 9:
        break
# Out:
# Politique Expected SARSA extraite (états connus) :
# État ('start',) → Action optimale : scissors
# État ('second', 'rock') → Action optimale : paper
# État ('second', 'paper') → Action optimale : paper
# État ('second', 'scissors') → Action optimale : rock
#
# Valeurs Q apprises (extrait) :
# État ('start',) → rock: 0.562, paper: -0.154, scissors: 0.669
# État ('second', 'rock') → rock: 0.0, paper: 1.0, scissors: -0.942
# État ('second', 'paper') → rock: -0.19, paper: 0.0, scissors: 0.0
# État ('second', 'scissors') → rock: 1.0, paper: -0.651, scissors: 0.0
