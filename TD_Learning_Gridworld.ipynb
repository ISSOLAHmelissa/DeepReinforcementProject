# %%
from Costum_environments.grid_world import GridWorld_MC

# %%
from DRL_algorithms.td_learning import expected_sarsa_control

# %%
from DRL_algorithms.utils import display_policy_console
import sys
sys.path.append("..")
from secret_envs.td_learning import q_learning

# %%
env = GridWorld_MC()

# %%
sarsa_policy, sarsa_Q = expected_sarsa_control(env, 10000, 0.9, 0.99, 0.9)
print(sarsa_policy)
print("alpha = 0.9 et epsilon = 0.9")
print(display_policy_console(sarsa_policy))
# Out:
# {0: 3, 5: 3, 10: 3, 11: 3, 15: 3, 20: 1, 21: 1, 22: 1, 23: 1, 6: 3, 7: 3, 1: 3, 2: 0, 12: 3, 17: 3, 16: 3, 18: 3, 13: 3, 14: 3, 9: 3, 8: 3, 3: 0, 19: 3}
# alpha = 0.9 et epsilon = 0.9
# S↓  ↓   ←   ←  <-4
#  ↓   ↓   ↓   ↓   ↓
#  ↓   ↓   ↓   ↓   ↓
#  ↓   ↓   ↓   ↓   ↓
#  →   →   →   →   F
# None

# %%
q_learning_policy, q_learning_Q = q_learning(env, 10000, 0.9, 0.99, 0.9)
print(q_learning_policy)
print("alpha = 0.9 et epsilon = 0.9")
print(display_policy_console(q_learning_policy))
