# %%
from Costum_environments.monty_hall_paradox import MontyHallLevel01Env
from DRL_algorithms.monty_carlo_methods import on_policy_fisrt_visit_mc_control

# %%
env =  MontyHallLevel01Env()
policy, Q = on_policy_fisrt_visit_mc_control(env,0.1,1000)
print(policy)
# Out:
# {('second_choice', 0, 1): {'keep': 0.05, 'switch': 0.9500000000000001}, ('second_choice', 0, 2): {'keep': 0.9500000000000001, 'switch': 0.05}, ('second_choice', 1, 0): {'keep': 0.05, 'switch': 0.9500000000000001}, ('second_choice', 1, 2): {'keep': 0.05, 'switch': 0.9500000000000001}, ('second_choice', 2, 0): {'keep': 0.05, 'switch': 0.9500000000000001}, ('second_choice', 2, 1): {'keep': 0.9500000000000001, 'switch': 0.05}, ('start', None, None): {0: 0.03333333333333333, 1: 0.9333333333333333, 2: 0.03333333333333333}}
